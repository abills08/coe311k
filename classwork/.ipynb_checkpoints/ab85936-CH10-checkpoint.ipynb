# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)
X = 10*np.random.rand(10)
X.sort()
Y = 10*np.random.rand(10)
A = np.vstack([X, np.ones(len(X))]).T
print("X:\n",X,"\nY:\n",Y)
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"\nSlope: {m}, Intercept: {c}")
mse = np.mean((Y - (X*m+c))**2)
print(f'Least Squared Mean Squared Error: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - (X*m+c))**2)
r_squared = 1 - (ss_res / ss_total)
print(f'Least Sqaured R-squared: {r_squared:.4f}\n')
degree = 3
coefficients = np.polyfit(X, Y, degree)
print("Polynomial Coefficients: ", coefficients)
polynomial = np.poly1d(coefficients)
y_pred = polynomial(X)
mse = np.mean((Y - y_pred)**2)
print(f'Polynomial Mean Squared Error: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'Polynomial R-squared: {r_squared:.4f}')
plt.scatter(X,Y)
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
plt.plot(np.linspace(0,10,100), m*np.linspace(0,10,100)+c, color='blue', label=f'least squares')
plt.legend()
plt.show()
# Out:
# X:
#  [3.83441519 4.23654799 4.37587211 5.44883183 5.48813504 6.02763376
#  6.45894113 7.15189366 8.91773001 9.63662761]
# Y:
#  [7.91725038 5.2889492  5.68044561 9.25596638 0.71036058 0.871293
#  0.20218397 8.32619846 7.78156751 8.70012148]
#
# Slope: 0.41898723950296984, Intercept: 2.8934515050568868
# Least Squared Mean Squared Error: 10.9912
# Least Sqaured R-squared: 0.0516
#
# Polynomial Coefficients:  [ -0.1909566    4.34880275 -30.88620196  73.2864309 ]
# Polynomial Mean Squared Error: 7.3269
# Polynomial R-squared: 0.3678

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)
X = 10*np.random.rand(10)
X.sort()
Y = 10*np.random.rand(10)

degree = 3
coefficients = np.polyfit(X, Y, degree)
print("Polynomial 3 Coefficients: ", coefficients)
polynomial = np.poly1d(coefficients)
y_pred = polynomial(X)
mse = np.mean((Y - y_pred)**2)
print(f'Polynomial 3 Mean Squared Error: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'Polynomial 3 R-squared: {r_squared:.4f}\n')
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree 3')

degree = 2
coefficients = np.polyfit(X, Y, degree)
print("Polynomial 2 Coefficients: ", coefficients)
polynomial = np.poly1d(coefficients)
y_pred = polynomial(X)
mse = np.mean((Y - y_pred)**2)
print(f'Polynomial 2 Mean Squared Error: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'Polynomial 2 R-squared: {r_squared:.4f}\n')
plt.plot(X, y_pred, color='blue', label=f'Polynomial fit of degree 2')

degree = 1
coefficients = np.polyfit(X, Y, degree)
print("Polynomial 1 Coefficients: ", coefficients)
polynomial = np.poly1d(coefficients)
y_pred = polynomial(X)
mse = np.mean((Y - y_pred)**2)
print(f'Polynomial 1 Mean Squared Error: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'Polynomial 1 R-squared: {r_squared:.4f}\n')
plt.plot(X, y_pred, color='black', label=f'Polynomial fit of degree 1')

degree = 4
coefficients = np.polyfit(X, Y, degree)
print("Polynomial 4 Coefficients: ", coefficients)
polynomial = np.poly1d(coefficients)
y_pred = polynomial(X)
mse = np.mean((Y - y_pred)**2)
print(f'Polynomial 4 Mean Squared Error: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'Polynomial 4 R-squared: {r_squared:.4f}\n')
plt.plot(X, y_pred, color='pink', label=f'Polynomial fit of degree 4')

degree = 5
coefficients = np.polyfit(X, Y, degree)
print("Polynomial 5 Coefficients: ", coefficients)
polynomial = np.poly1d(coefficients)
y_pred = polynomial(X)
mse = np.mean((Y - y_pred)**2)
print(f'Polynomial 5 Mean Squared Error: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'Polynomial 5 R-squared: {r_squared:.4f}\n')
plt.plot(X, y_pred, color='green', label=f'Polynomial fit of degree 5')

degree = 6
coefficients = np.polyfit(X, Y, degree)
print("Polynomial 6 Coefficients: ", coefficients)
polynomial = np.poly1d(coefficients)
y_pred = polynomial(X)
mse = np.mean((Y - y_pred)**2)
print(f'Polynomial 6 Mean Squared Error: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'Polynomial 6 R-squared: {r_squared:.4f}\n')
plt.plot(X, y_pred, color='brown', label=f'Polynomial fit of degree 6')

plt.scatter(X,Y)
plt.legend()
plt.show()
# Out:
# Polynomial 3 Coefficients:  [-4.63041291e-03  2.06451301e-01 -1.40131331e+00  6.56477331e+00]
# Polynomial 3 Mean Squared Error: 3.9930
# Polynomial 3 R-squared: 0.3434
#
# Polynomial 2 Coefficients:  [ 0.13073306 -1.05904603  6.20972438]
# Polynomial 2 Mean Squared Error: 3.9974
# Polynomial 2 R-squared: 0.3427
#
# Polynomial 1 Coefficients:  [0.36692588 3.42530468]
# Polynomial 1 Mean Squared Error: 4.9606
# Polynomial 1 R-squared: 0.1843
#
# Polynomial 4 Coefficients:  [ -0.05662781   1.29741365  -9.92337192  28.49902417 -17.89952849]
# Polynomial 4 Mean Squared Error: 2.7099
# Polynomial 4 R-squared: 0.5544
#
# Polynomial 5 Coefficients:  [ 1.49349351e-02 -4.80215156e-01  5.78354162e+00 -3.16751010e+01
#   7.51286220e+01 -5.02984333e+01]
# Polynomial 5 Mean Squared Error: 2.2180
# Polynomial 5 R-squared: 0.6353
#
# Polynomial 6 Coefficients:  [-4.23719971e-03  1.53800778e-01 -2.25970124e+00  1.70317036e+01
#  -6.79468599e+01  1.30341493e+02 -8.07529856e+01]
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)
X = 10*np.random.rand(10)
X.sort()
Y = 10*np.random.rand(10)
degree = 3
V = np.vander(X, N=degree+1, increasing=True)
VT_V = np.dot(V.T, V)
VT_y = np.dot(V.T, Y)
coefficients = np.linalg.solve(VT_V, VT_y)
polynomial = np.poly1d(coefficients[::-1])
y_pred = polynomial(X)
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')
ss_total = np.sum((Y - np.mean(Y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}\n')
plt.scatter(X,Y)
plt.plot(X, y_pred, color='red')
plt.show()
# Out:
# Mean Squared Error: 7.3269
# R-squared: 0.3678
