# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 1, 0, 1, 0, 1])
cs = CubicSpline(x, y, bc_type='natural')
x_interp = np.linspace(0, 5, 100)
y_interp = cs(x_interp)
cs_clamped = CubicSpline(x, y, bc_type=((1, 0), (1, 0)))
y_clamped_interp = cs_clamped(x_interp)
plt.scatter(x, y)
plt.plot(x_interp, y_clamped_interp, 'g-', label="Clamped Spline Interpolation")
degree = 5
coefficients = np.polyfit(x, y, degree)
polynomial = np.poly1d(coefficients)
y_pred = polynomial(np.linspace(0,5,100))
plt.plot(np.linspace(0,5,100), y_pred, color='red', label=f'Polynomial fit of degree {degree}')
plt.legend()
plt.show()
