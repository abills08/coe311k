# %%
import numpy as np
# Data points
X = np.array([1, 2, 3, 4, 5])
Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])
# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T
print("X:")
print(X)
print("Y:")
print(Y)
print("A:")
print(A)
# Out:
# X:
# [1 2 3 4 5]
# Y:
# [1.2 2.8 3.6 4.5 5.1]
# A:
# [[1. 1.]
#  [2. 1.]
#  [3. 1.]
#  [4. 1.]
#  [5. 1.]]

# %%
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %%
import matplotlib.pyplot as plt

plt.scatter(X,Y)
plt.plot(np.linspace(0,5,50), m*np.linspace(0,5,50)+c)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

X1 = 10*np.random.rand(10)
Y1 = 10*np.random.rand(10)
A1 = np.vstack([X1, np.ones(len(X1))]).T
print("X:\n",X1,"\nY:\n",Y1)
m1, c1 = np.linalg.lstsq(A1, Y1, rcond=None)[0]
print(f"Slope: {m1}, Intercept: {c1}")
plt.scatter(X1,Y1)
plt.plot(np.linspace(0,10,100), m1*np.linspace(0,10,100)+c1)
plt.show()
# Out:
# X:
#  [3.17108113 4.8637606  4.29013356 6.38083179 7.37859381 2.53829124
#  3.82791219 5.23650094 5.02054712 9.96325312]
# Y:
#  [8.24439214 3.88040366 4.40971994 3.04901635 7.440311   6.99420388
#  4.99656998 6.88802188 5.65913862 1.02358196]
# Slope: -0.6330914354830482, Intercept: 8.593085858993156
