# %% [markdown]
# 6A

# %%
import numpy as np
import time

def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

A = ([[10,-1,2,0,0],[-1,11,-1,3,0],[2,-1,10,-1,0],[0,3,-1,8,-2],[0,0,0,-2,9]])
b = ([14,30,26,25,37])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
timeJ = time.time()
xJ, iterationsJ = jacobi(A,b,x0,tol,max_iterations)
timeJ = time.time() - timeJ
timeGS = time.time()
xGS, iterationsGS = gauss_seidel(A,b,x0,tol,max_iterations)
timeGS = time.time() - timeGS
print(iterationsJ, timeJ)
print(iterationsGS, timeGS)
# Out:
# 1 0.0004494190216064453
# 2 0.0003819465637207031

# %% [markdown]
# Both methods converged, Gauss-Seidel took less time but did more iterations

# %% [markdown]
# 6B

# %%
A = ([[1,2,3,0,0],[2,1,2,3,0],[3,2,1,2,3],[0,3,2,1,2],[0,0,3,2,1]])
b = ([14,22,33,26,22])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
timeJ = time.time()
xJ, iterationsJ = jacobi(A,b,x0,tol,max_iterations)
timeJ = time.time() - timeJ
timeGS = time.time()
xGS, iterationsGS = gauss_seidel(A,b,x0,tol,max_iterations)
timeGS = time.time() - timeGS
print(iterationsJ, timeJ)
print(iterationsGS, timeGS)
# Out:
# 100 0.010403871536254883
# 100 0.007741689682006836
# <ipython-input-5-7b10c789bfaa>:10: RuntimeWarning: overflow encountered in long_scalars
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)
# <ipython-input-5-7b10c789bfaa>:24: RuntimeWarning: overflow encountered in long_scalars
#   s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
# <ipython-input-5-7b10c789bfaa>:25: RuntimeWarning: overflow encountered in long_scalars
#   s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
# <ipython-input-5-7b10c789bfaa>:26: RuntimeWarning: overflow encountered in long_scalars
#   x_new[i] = (b[i] - s1 - s2) / A[i][i]

# %% [markdown]
# Neither method converged because the array was not diagonally dominant.
